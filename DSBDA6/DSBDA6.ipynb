# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score

# %%
df = pd.read_csv("C:/PythonXYZ/DSBDA/DSBDA6/iris_sample.csv")
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width    species
# 0           5.1          3.5           1.4          0.2     setosa
# 1           4.9          3.0           1.4          0.2     setosa
# 2           4.7          3.2           1.3          0.2     setosa
# 3           6.0          2.2           5.0          1.5  virginica
# 4           5.4          3.9           1.7          0.4     setosa

# %%
x = df[['sepal_length', 'sepal_width', 'petal_length', 'petal_width']]
y = df['species']

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25, random_state=42)

# %%
model = GaussianNB()
model.fit(x_train, y_train)
# Out:
# GaussianNB()

# %%
y_pred = model.predict(x_test)
print(y_pred)
# Out:
# ['setosa' 'setosa']

# %%
cm = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:\n", cm)
# Out:
# Confusion Matrix:
#  [[2]]
# C:\Users\swara\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\metrics\_classification.py:407: UserWarning: A single label was found in 'y_true' and 'y_pred'. For the confusion matrix to have the correct shape, use the 'labels' parameter to pass all known labels.
#   warnings.warn(

# %%
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 1.0

# %%
error_rate = 1 - accuracy
print("Error Rate:", error_rate)
# Out:
# Error Rate: 0.0

# %%
precision = precision_score(y_test, y_pred, average='macro')
print("Precision (macro):", precision)
# Out:
# Precision (macro): 1.0

# %%
recall = recall_score(y_test, y_pred, average='macro')
print("Recall (macro):", recall)
# Out:
# Recall (macro): 1.0

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=model.classes_, yticklabels=model.classes_)
plt.title("Confusion Matrix Heatmap")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()
