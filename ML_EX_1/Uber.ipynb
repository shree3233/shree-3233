# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
import pandas as pd

# %%
uber = pd.read_csv('C:/Users/swara/OneDrive/Desktop/LP-3/ML_EX_1/uber.csv')
uber.head()
# Out:
#    Unnamed: 0                            key  fare_amount  \
# 0    24238194    2015-05-07 19:52:06.0000003          7.5
# 1    27835199    2009-07-17 20:04:56.0000002          7.7
# 2    44984355   2009-08-24 21:45:00.00000061         12.9
# 3    25894730    2009-06-26 08:22:21.0000001          5.3
# 4    17610152  2014-08-28 17:47:00.000000188         16.0
#
#            pickup_datetime  pickup_longitude  pickup_latitude  \
# 0  2015-05-07 19:52:06 UTC        -73.999817        40.738354
# 1  2009-07-17 20:04:56 UTC        -73.994355        40.728225
# 2  2009-08-24 21:45:00 UTC        -74.005043        40.740770
# 3  2009-06-26 08:22:21 UTC        -73.976124        40.790844
# 4  2014-08-28 17:47:00 UTC        -73.925023        40.744085
#
#    dropoff_longitude  dropoff_latitude  passenger_count
# 0         -73.999512         40.723217                1
# 1         -73.994710         40.750325                1
# 2         -73.962565         40.772647                1
# 3         -73.965316         40.803349                3
# 4         -73.973082         40.761247                5

# %%
 uber.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200000 entries, 0 to 199999
# Data columns (total 9 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Unnamed: 0         200000 non-null  int64
#  1   key                200000 non-null  object
#  2   fare_amount        200000 non-null  float64
#  3   pickup_datetime    200000 non-null  object
#  4   pickup_longitude   200000 non-null  float64
#  5   pickup_latitude    200000 non-null  float64
#  6   dropoff_longitude  199999 non-null  float64
#  7   dropoff_latitude   199999 non-null  float64
#  8   passenger_count    200000 non-null  int64
# dtypes: float64(5), int64(2), object(2)
# memory usage: 13.7+ MB

# %%
 uber.isnull().sum()
# Out:
# Unnamed: 0           0
# key                  0
# fare_amount          0
# pickup_datetime      0
# pickup_longitude     0
# pickup_latitude      0
# dropoff_longitude    1
# dropoff_latitude     1
# passenger_count      0
# dtype: int64

# %%
uber_2 = uber.drop(['Unnamed: 0','key'],axis=1)
uber_2.dropna(axis=0,inplace=True)

# %%
uber_2.isnull().sum()
 #uber_2.describe()
# Out:
# fare_amount          0
# pickup_datetime      0
# pickup_longitude     0
# pickup_latitude      0
# dropoff_longitude    0
# dropoff_latitude     0
# passenger_count      0
# dtype: int64

# %%
def haversine (lon_1, lon_2, lat_1, lat_2):
    
    lon_1, lon_2, lat_1, lat_2 = map(np.radians, [lon_1, lon_2, lat_1, lat_2])  #Degrees to Radians
    
    
    diff_lon = lon_2 - lon_1
    diff_lat = lat_2 - lat_1
    

    km = 2 * 6371 * np.arcsin(np.sqrt(np.sin(diff_lat/2.0)**2 + 
                                      np.cos(lat_1) * np.cos(lat_2) * np.sin(diff_lon/2.0)**2))
    
    return km

# %%
uber_2['Distance']= haversine(uber_2['pickup_longitude'],uber_2['dropoff_longitude'],
                             uber_2['pickup_latitude'],uber_2['dropoff_latitude'])

uber_2['Distance'] = uber_2['Distance'].astype(float).round(2)    # Round-off Optional

# %%
uber_2.head()
# Out:
#    fare_amount          pickup_datetime  pickup_longitude  pickup_latitude  \
# 0          7.5  2015-05-07 19:52:06 UTC        -73.999817        40.738354
# 1          7.7  2009-07-17 20:04:56 UTC        -73.994355        40.728225
# 2         12.9  2009-08-24 21:45:00 UTC        -74.005043        40.740770
# 3          5.3  2009-06-26 08:22:21 UTC        -73.976124        40.790844
# 4         16.0  2014-08-28 17:47:00 UTC        -73.925023        40.744085
#
#    dropoff_longitude  dropoff_latitude  passenger_count  Distance
# 0         -73.999512         40.723217                1      1.68
# 1         -73.994710         40.750325                1      2.46
# 2         -73.962565         40.772647                1      5.04
# 3         -73.965316         40.803349                3      1.66
# 4         -73.973082         40.761247                5      4.48

# %%
plt.scatter(uber_2['Distance'], uber_2['fare_amount'])
plt.xlabel("Distance")
plt.ylabel("fare_amount")
# Out:
# Text(0, 0.5, 'fare_amount')

# %%
uber_2.drop(uber_2[uber_2['Distance'] > 60].index, inplace = True)
uber_2.drop(uber_2[uber_2['Distance'] == 0].index, inplace = True)
uber_2.drop(uber_2[uber_2['fare_amount'] == 0].index, inplace = True)
uber_2.drop(uber_2[uber_2['fare_amount'] < 0].index, inplace = True)

# %%
uber_2.drop(uber_2[(uber_2['fare_amount']>100) & (uber_2['Distance']<1)].index, inplace = True )
uber_2.drop(uber_2[(uber_2['fare_amount']<100) & (uber_2['Distance']>100)].index, inplace = True )

# %%
uber_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 193481 entries, 0 to 199999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   fare_amount        193481 non-null  float64
#  1   pickup_datetime    193481 non-null  object
#  2   pickup_longitude   193481 non-null  float64
#  3   pickup_latitude    193481 non-null  float64
#  4   dropoff_longitude  193481 non-null  float64
#  5   dropoff_latitude   193481 non-null  float64
#  6   passenger_count    193481 non-null  int64
#  7   Distance           193481 non-null  float64
# dtypes: float64(6), int64(1), object(1)
# memory usage: 13.3+ MB

# %%
plt.scatter(uber_2['Distance'], uber_2['fare_amount'])
plt.xlabel("Distance")
plt.ylabel("fare_amount")
# Out:
# Text(0, 0.5, 'fare_amount')

# %%
uber_2['pickup_datetime'] = pd.to_datetime(uber_2['pickup_datetime'])

uber_2['Year'] = uber_2['pickup_datetime'].apply(lambda time: time.year)
uber_2['Month'] = uber_2['pickup_datetime'].apply(lambda time: time.month)
uber_2['Day'] = uber_2['pickup_datetime'].apply(lambda time: time.day)
uber_2['Day of Week'] = uber_2['pickup_datetime'].apply(lambda time: time.dayofweek)
uber_2['Day of Week_num'] = uber_2['pickup_datetime'].apply(lambda time: time.dayofweek)
uber_2['Hour'] = uber_2['pickup_datetime'].apply(lambda time: time.hour)

day_map = {0:'Mon',1:'Tue',2:'Wed',3:'Thu',4:'Fri',5:'Sat',6:'Sun'}
uber_2['Day of Week'] = uber_2['Day of Week'].map(day_map)

uber_2['counter'] = 1

# %%
uber_2['pickup'] = uber_2['pickup_latitude'].astype(str) + "," + uber_2['pickup_longitude'].astype(str)   
uber_2['drop off'] = uber_2['dropoff_latitude'].astype(str) + "," + uber_2['dropoff_longitude'].astype(str)

# %%
uber_2.head()
# Out:
#    fare_amount           pickup_datetime  pickup_longitude  pickup_latitude  \
# 0          7.5 2015-05-07 19:52:06+00:00        -73.999817        40.738354
# 1          7.7 2009-07-17 20:04:56+00:00        -73.994355        40.728225
# 2         12.9 2009-08-24 21:45:00+00:00        -74.005043        40.740770
# 3          5.3 2009-06-26 08:22:21+00:00        -73.976124        40.790844
# 4         16.0 2014-08-28 17:47:00+00:00        -73.925023        40.744085
#
#    dropoff_longitude  dropoff_latitude  passenger_count  Distance  Year  \
# 0         -73.999512         40.723217                1      1.68  2015
# 1         -73.994710         40.750325                1      2.46  2009
# 2         -73.962565         40.772647                1      5.04  2009
# 3         -73.965316         40.803349                3      1.66  2009
# 4         -73.973082         40.761247                5      4.48  2014
#
#    Month  Day Day of Week  Day of Week_num  Hour  counter  \
# 0      5    7         Thu                3    19        1
# 1      7   17         Fri                4    20        1
# 2      8   24         Mon                0    21        1
# 3      6   26         Fri                4     8        1
# 4      8   28         Thu                3    17        1
#
#                                  pickup                           drop off
# 0  40.73835372924805,-73.99981689453125  40.72321701049805,-73.99951171875
# 1                  40.728225,-73.994355                40.750325,-73.99471
# 2                   40.74077,-74.005043               40.772647,-73.962565
# 3                  40.790844,-73.976124               40.803349,-73.965316
# 4                  40.744085,-73.925023       40.761247,-73.97308199999999

# %%
no_of_trips = []
year = [2009, 2010, 2011, 2012, 2013, 2014, 2015]

colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd',
          '#8c564b', '#e377c2', '#7f7f7f', '#bcbd22', '#17becf']

for i in range(2009, 2016):
    x = uber_2.loc[uber_2['Year'] == i, 'counter'].sum()
    no_of_trips.append(x)

print("Average trips a year: ")
print(year, no_of_trips)

plt.bar(year, no_of_trips, color=colors)
# Out:
# Average trips a year:
# [2009, 2010, 2011, 2012, 2013, 2014, 2015] [np.int64(29674), np.int64(29094), np.int64(30712), np.int64(31138), np.int64(30365), np.int64(29065), np.int64(13433)]
# <BarContainer object of 7 artists>

# %%
no_of_trips = []
month = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']

colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd',
          '#8c564b', '#e377c2', '#7f7f7f', '#bcbd22', '#17becf']

for i in range(1, 13):
    x = uber_2.loc[uber_2['Month'] == i, 'counter'].sum()
    no_of_trips.append(x)

print("Average trips a Month: ")
print(month, no_of_trips)

plt.bar(month, no_of_trips, color=colors)
# Out:
# Average trips a Month:
# ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'] [np.int64(17126), np.int64(16141), np.int64(18165), np.int64(18004), np.int64(18259), np.int64(17210), np.int64(14583), np.int64(13664), np.int64(14772), np.int64(15690), np.int64(14824), np.int64(15043)]
# <BarContainer object of 12 artists>

# %%
no_of_trips = []
day = ['Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat', 'Sun']

colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd',
          '#8c564b', '#e377c2', '#7f7f7f', '#bcbd22', '#17becf']

for i in range(0, 7):
    x = uber_2.loc[uber_2['Day of Week_num'] == i, 'counter'].sum()
    no_of_trips.append(x)

print("Average trips by Days: ")
print(day, no_of_trips)

plt.bar(day, no_of_trips, color=colors)
# Out:
# Average trips by Days:
# ['Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat', 'Sun'] [np.int64(24377), np.int64(27236), np.int64(28084), np.int64(29041), np.int64(29865), np.int64(29306), np.int64(25572)]
# <BarContainer object of 7 artists>

# %%
year_vs_trips = uber_2.groupby(['Year','Month']).agg( 
    no_of_trips = ('counter','count'),
    Average_fair = ('fare_amount','mean'),
    Total_fair = ('fare_amount','sum'),
    Avg_distance = ( 'Distance', 'mean')).reset_index()

year_vs_trips['avg_no_of_trips'] = year_vs_trips['no_of_trips']/30
year_vs_trips['month_year'] = year_vs_trips['Month'].astype(str) +", "+ year_vs_trips['Year'].astype(str)


year_vs_trips = year_vs_trips.reset_index()

year_vs_trips.head()


year_vs_trips.plot(kind='line',x='month_year',y='no_of_trips', xlabel='January, 2009 - June, 2015',
    ylabel='No of Trips', title='No of trips vs Months')
# Out:
# <Axes: title={'center': 'No of trips vs Months'}, xlabel='January, 2009 - June, 2015', ylabel='No of Trips'>

# %%
import seaborn as sns

df_1 = uber_2[['Distance', 'Day of Week_num', 'Hour']].copy()

df_h = df_1.copy()

df_h = df_h.groupby(['Hour', 'Day of Week_num']).mean()
df_h = df_h.unstack(level=0)

# %%
fig, ax = plt.subplots(figsize=(24, 7))
sns.heatmap(df_h, cmap="Reds",
           linewidth=0.3, cbar_kws={"shrink": .8})

xticks_labels = ['12 AM', '01 AM', '02 AM ', '03 AM ', '04 AM ', '05 AM ', '06 AM ', '07 AM ', 
                 '08 AM ', '09 AM ', '10 AM ', '11 AM ', '12 PM ', '01 PM ', '02 PM ', '03 PM ',
                 '04 PM ', '05 PM ', '06 PM ', '07 PM ', '08 PM ', '09 PM ', '10 PM ', '11 PM ']

yticks_labels = ['Mon','Tue','Wed','Thu','Fri','Sat','Sun']

plt.xticks(np.arange(24) + .5, labels=xticks_labels)
plt.yticks(np.arange(7) + .5, labels=yticks_labels)

ax.xaxis.tick_top()

title = 'Weekly Uber Rides'.upper()
plt.title(title, fontdict={'fontsize': 25})

plt.show()

# %%
plt.figure(figsize=[8,4])
sns.distplot(uber_2['fare_amount'], color='g',hist_kws=dict(edgecolor="black", linewidth=2), bins=30)
plt.title('Target Variable Distribution')
plt.show()
# Out:
# C:\Users\swara\AppData\Local\Temp\ipykernel_1908\838148572.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(uber_2['fare_amount'], color='g',hist_kws=dict(edgecolor="black", linewidth=2), bins=30)

# %%
import statistics as st

print("Mean of fare prices is % s "
         % (st.mean(uber_2['fare_amount'])))

print("Median of fare prices is % s "
         % (st.median(uber_2['fare_amount'])))

print("Standard Deviation of Fare Prices is % s "
                % (st.stdev(uber_2['fare_amount'])))
# Out:
# Mean of fare prices is 11.311137476031238
# Median of fare prices is 8.5
# Standard Deviation of Fare Prices is 9.501354886915946

# %%
import statistics as st

print("Mean of Distance is % s "
         % (st.mean(uber_2['Distance'])))

print("Median of Distance is % s "
         % (st.median(uber_2['Distance'])))

print("Standard Deviation of Distance is % s "
                % (st.stdev(uber_2['Distance'])))
# Out:
# Mean of Distance is 3.3573488352861522
# Median of Distance is 2.18
# Standard Deviation of Distance is 3.5995030824386185

# %%
corr = uber_2.corr(numeric_only=True)
corr.style.background_gradient(cmap='BuGn')
# Out:
# C:\Users\swara\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\formats\style.py:3807: RuntimeWarning: All-NaN slice encountered
#   smin = np.nanmin(gmap) if vmin is None else vmin
# C:\Users\swara\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\formats\style.py:3808: RuntimeWarning: All-NaN slice encountered
#   smax = np.nanmax(gmap) if vmax is None else vmax
# <style type="text/css">
# #T_a209e_row0_col0, #T_a209e_row1_col1, #T_a209e_row1_col3, #T_a209e_row2_col2, #T_a209e_row3_col1, #T_a209e_row3_col3, #T_a209e_row4_col4, #T_a209e_row5_col5, #T_a209e_row6_col6, #T_a209e_row7_col7, #T_a209e_row8_col8, #T_a209e_row9_col9, #T_a209e_row10_col10, #T_a209e_row11_col11 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_a209e_row0_col1, #T_a209e_row7_col1, #T_a209e_row7_col3 {
#   background-color: #64c1a2;
#   color: #000000;
# }
# #T_a209e_row0_col2, #T_a209e_row5_col2, #T_a209e_row10_col2 {
#   background-color: #6dc5a9;
#   color: #000000;
# }
# #T_a209e_row0_col3, #T_a209e_row5_col1, #T_a209e_row5_col3, #T_a209e_row6_col1, #T_a209e_row6_col3, #T_a209e_row8_col4, #T_a209e_row10_col1, #T_a209e_row10_col3 {
#   background-color: #65c2a3;
#   color: #000000;
# }
# #T_a209e_row0_col4, #T_a209e_row5_col4, #T_a209e_row8_col1, #T_a209e_row8_col3, #T_a209e_row10_col4 {
#   background-color: #68c3a6;
#   color: #000000;
# }
# #T_a209e_row0_col5, #T_a209e_row2_col1, #T_a209e_row2_col3, #T_a209e_row5_col9, #T_a209e_row6_col9, #T_a209e_row10_col0, #T_a209e_row10_col9, #T_a209e_row11_col5, #T_a209e_row11_col9 {
#   background-color: #f4fbfc;
#   color: #000000;
# }
# #T_a209e_row0_col6, #T_a209e_row6_col0 {
#   background-color: #006529;
#   color: #f1f1f1;
# }
# #T_a209e_row0_col7 {
#   background-color: #d4efec;
#   color: #000000;
# }
# #T_a209e_row0_col8, #T_a209e_row6_col7 {
#   background-color: #e5f5f9;
#   color: #000000;
# }
# #T_a209e_row0_col9, #T_a209e_row1_col5, #T_a209e_row3_col5, #T_a209e_row6_col5, #T_a209e_row8_col5, #T_a209e_row9_col0 {
#   background-color: #f5fbfc;
#   color: #000000;
# }
# #T_a209e_row0_col10, #T_a209e_row1_col10, #T_a209e_row3_col10, #T_a209e_row7_col10, #T_a209e_row9_col8, #T_a209e_row9_col10, #T_a209e_row9_col11 {
#   background-color: #ebf7fa;
#   color: #000000;
# }
# #T_a209e_row0_col11, #T_a209e_row7_col6 {
#   background-color: #eff9fb;
#   color: #000000;
# }
# #T_a209e_row0_col12, #T_a209e_row1_col12, #T_a209e_row2_col12, #T_a209e_row3_col12, #T_a209e_row4_col12, #T_a209e_row5_col12, #T_a209e_row6_col12, #T_a209e_row7_col12, #T_a209e_row8_col12, #T_a209e_row9_col12, #T_a209e_row10_col12, #T_a209e_row11_col12, #T_a209e_row12_col0, #T_a209e_row12_col1, #T_a209e_row12_col2, #T_a209e_row12_col3, #T_a209e_row12_col4, #T_a209e_row12_col5, #T_a209e_row12_col6, #T_a209e_row12_col7, #T_a209e_row12_col8, #T_a209e_row12_col9, #T_a209e_row12_col10, #T_a209e_row12_col11, #T_a209e_row12_col12 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_a209e_row1_col0, #T_a209e_row3_col0, #T_a209e_row4_col6 {
#   background-color: #f3fafc;
#   color: #000000;
# }
# #T_a209e_row1_col2, #T_a209e_row1_col4, #T_a209e_row2_col5, #T_a209e_row2_col9, #T_a209e_row3_col2, #T_a209e_row3_col4, #T_a209e_row4_col1, #T_a209e_row4_col3, #T_a209e_row4_col5, #T_a209e_row4_col9, #T_a209e_row7_col8, #T_a209e_row8_col7, #T_a209e_row8_col9, #T_a209e_row10_col11, #T_a209e_row11_col0, #T_a209e_row11_col6, #T_a209e_row11_col10 {
#   background-color: #f7fcfd;
#   color: #000000;
# }
# #T_a209e_row1_col6, #T_a209e_row1_col9, #T_a209e_row2_col6, #T_a209e_row3_col6, #T_a209e_row3_col9, #T_a209e_row5_col0, #T_a209e_row5_col6, #T_a209e_row9_col6 {
#   background-color: #f2fafc;
#   color: #000000;
# }
# #T_a209e_row1_col7, #T_a209e_row2_col8, #T_a209e_row3_col7, #T_a209e_row4_col8, #T_a209e_row5_col8, #T_a209e_row5_col10, #T_a209e_row6_col8 {
#   background-color: #e7f6f9;
#   color: #000000;
# }
# #T_a209e_row1_col8, #T_a209e_row3_col8, #T_a209e_row6_col10, #T_a209e_row10_col8, #T_a209e_row11_col8 {
#   background-color: #e9f7fa;
#   color: #000000;
# }
# #T_a209e_row1_col11, #T_a209e_row3_col11, #T_a209e_row4_col11, #T_a209e_row7_col11 {
#   background-color: #ecf8fa;
#   color: #000000;
# }
# #T_a209e_row2_col0, #T_a209e_row4_col0, #T_a209e_row7_col9 {
#   background-color: #f6fcfd;
#   color: #000000;
# }
# #T_a209e_row2_col4, #T_a209e_row4_col2 {
#   background-color: #004a1e;
#   color: #f1f1f1;
# }
# #T_a209e_row2_col7, #T_a209e_row4_col7, #T_a209e_row5_col11, #T_a209e_row9_col7 {
#   background-color: #eaf7fa;
#   color: #000000;
# }
# #T_a209e_row2_col10, #T_a209e_row4_col10, #T_a209e_row8_col10 {
#   background-color: #edf8fb;
#   color: #000000;
# }
# #T_a209e_row2_col11, #T_a209e_row8_col11 {
#   background-color: #ecf8fb;
#   color: #000000;
# }
# #T_a209e_row5_col7, #T_a209e_row10_col7, #T_a209e_row11_col7 {
#   background-color: #e8f6fa;
#   color: #000000;
# }
# #T_a209e_row6_col2, #T_a209e_row7_col4, #T_a209e_row8_col2, #T_a209e_row9_col4 {
#   background-color: #6ac4a7;
#   color: #000000;
# }
# #T_a209e_row6_col4, #T_a209e_row11_col1, #T_a209e_row11_col3, #T_a209e_row11_col4 {
#   background-color: #67c2a5;
#   color: #000000;
# }
# #T_a209e_row6_col11, #T_a209e_row10_col6 {
#   background-color: #f0f9fb;
#   color: #000000;
# }
# #T_a209e_row7_col0 {
#   background-color: #e3f4f7;
#   color: #000000;
# }
# #T_a209e_row7_col2, #T_a209e_row9_col2 {
#   background-color: #6fc6aa;
#   color: #000000;
# }
# #T_a209e_row7_col5, #T_a209e_row9_col5 {
#   background-color: #f5fbfd;
#   color: #000000;
# }
# #T_a209e_row8_col0, #T_a209e_row8_col6, #T_a209e_row10_col5 {
#   background-color: #f1fafc;
#   color: #000000;
# }
# #T_a209e_row9_col1, #T_a209e_row9_col3 {
#   background-color: #63c0a0;
#   color: #000000;
# }
# #T_a209e_row11_col2 {
#   background-color: #6cc4a8;
#   color: #000000;
# }
# </style>
# <table id="T_a209e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a209e_level0_col0" class="col_heading level0 col0" >fare_amount</th>
#       <th id="T_a209e_level0_col1" class="col_heading level0 col1" >pickup_longitude</th>
#       <th id="T_a209e_level0_col2" class="col_heading level0 col2" >pickup_latitude</th>
#       <th id="T_a209e_level0_col3" class="col_heading level0 col3" >dropoff_longitude</th>
#       <th id="T_a209e_level0_col4" class="col_heading level0 col4" >dropoff_latitude</th>
#       <th id="T_a209e_level0_col5" class="col_heading level0 col5" >passenger_count</th>
#       <th id="T_a209e_level0_col6" class="col_heading level0 col6" >Distance</th>
#       <th id="T_a209e_level0_col7" class="col_heading level0 col7" >Year</th>
#       <th id="T_a209e_level0_col8" class="col_heading level0 col8" >Month</th>
#       <th id="T_a209e_level0_col9" class="col_heading level0 col9" >Day</th>
#       <th id="T_a209e_level0_col10" class="col_heading level0 col10" >Day of Week_num</th>
#       <th id="T_a209e_level0_col11" class="col_heading level0 col11" >Hour</th>
#       <th id="T_a209e_level0_col12" class="col_heading level0 col12" >counter</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a209e_level0_row0" class="row_heading level0 row0" >fare_amount</th>
#       <td id="T_a209e_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_a209e_row0_col1" class="data row0 col1" >0.012070</td>
#       <td id="T_a209e_row0_col2" class="data row0 col2" >-0.008682</td>
#       <td id="T_a209e_row0_col3" class="data row0 col3" >0.010555</td>
#       <td id="T_a209e_row0_col4" class="data row0 col4" >-0.008695</td>
#       <td id="T_a209e_row0_col5" class="data row0 col5" >0.013508</td>
#       <td id="T_a209e_row0_col6" class="data row0 col6" >0.893050</td>
#       <td id="T_a209e_row0_col7" class="data row0 col7" >0.123562</td>
#       <td id="T_a209e_row0_col8" class="data row0 col8" >0.024402</td>
#       <td id="T_a209e_row0_col9" class="data row0 col9" >-0.000286</td>
#       <td id="T_a209e_row0_col10" class="data row0 col10" >0.005140</td>
#       <td id="T_a209e_row0_col11" class="data row0 col11" >-0.019788</td>
#       <td id="T_a209e_row0_col12" class="data row0 col12" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_a209e_level0_row1" class="row_heading level0 row1" >pickup_longitude</th>
#       <td id="T_a209e_row1_col0" class="data row1 col0" >0.012070</td>
#       <td id="T_a209e_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_a209e_row1_col2" class="data row1 col2" >-0.949099</td>
#       <td id="T_a209e_row1_col3" class="data row1 col3" >0.999883</td>
#       <td id="T_a209e_row1_col4" class="data row1 col4" >-0.993975</td>
#       <td id="T_a209e_row1_col5" class="data row1 col5" >0.009174</td>
#       <td id="T_a209e_row1_col6

# %%
X = uber_2['Distance'].values.reshape(-1, 1)        #Independent Variable
y = uber_2['fare_amount'].values.reshape(-1, 1)     #Dependent Variable

# %%
from sklearn.preprocessing import StandardScaler
std = StandardScaler()
y_std = std.fit_transform(y)
print(y_std)

x_std = std.fit_transform(X)
print(x_std)
# Out:
# [[-0.4011162 ]
#  [-0.38006651]
#  [ 0.16722527]
#  ...
#  [ 2.06169682]
#  [ 0.33562274]
#  [ 0.29352337]]
# [[-0.46599576]
#  [-0.24929862]
#  [ 0.46746884]
#  ...
#  [ 2.63721838]
#  [ 0.05074357]
#  [ 0.57303924]]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x_std, y_std, test_size=0.2, random_state=0)

# %%
from sklearn.linear_model import LinearRegression
l_reg = LinearRegression()
l_reg.fit(X_train, y_train)

print("Training set score: {:.2f}".format(l_reg.score(X_train, y_train)))
print("Test set score: {:.7f}".format(l_reg.score(X_test, y_test)))
# Out:
# Training set score: 0.80
# Test set score: 0.8006071

# %%
# %pip install tabulate
# Out:
# Collecting tabulate
#   Downloading tabulate-0.9.0-py3-none-any.whl.metadata (34 kB)
# Downloading tabulate-0.9.0-py3-none-any.whl (35 kB)
# Installing collected packages: tabulate
# Successfully installed tabulate-0.9.0
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
from tabulate import tabulate
y_pred = l_reg.predict(X_test)
# Ensure both are 1D
y_test_flat = y_test.ravel() if hasattr(y_test, "ravel") else y_test
y_pred_flat = y_pred.ravel() if hasattr(y_pred, "ravel") else y_pred
df = pd.DataFrame({
    'Actual': y_test_flat,
    'Predicted': y_pred_flat
 })
print(tabulate(df.head(10), headers='keys', tablefmt='psql'))
# Out:
# +----+------------+-------------+
# |    |     Actual |   Predicted |
# |----+------------+-------------|
# |  0 | -0.548464  |  -0.663476  |
# |  1 | -0.769486  |  -0.611449  |
# |  2 |  0.651368  |   0.290356  |
# |  3 |  6.86102   |   3.52595   |
# |  4 | -0.611613  |  -0.544557  |
# |  5 | -0.16957   |  -0.333971  |
# |  6 | -0.295868  |  -0.0490599 |
# |  7 | -0.0853709 |  -0.224961  |
# |  8 | -0.506365  |  -0.517305  |
# |  9 | -0.558989  |  -0.628792  |
# +----+------------+-------------+

# %%
from sklearn import metrics
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))
#print('Mean Absolute % Error:', metrics.mean_absolute_percentage_error(y_test, y_pred))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Mean Absolute Error: 0.23979020298617207
# Mean Squared Error: 0.19845894128014663
# Root Mean Squared Error: 0.44548730765325584

# %%
print(l_reg.intercept_)
print(l_reg.coef_)
# Out:
# [-0.00016705]
# [[0.89176936]]

# %%
plt.subplot(2, 2, 1)
plt.scatter(X_train, y_train, color = 'red')
plt.plot(X_train, l_reg.predict(X_train), color ="blue")
plt.title("Fare vs Distance (Training Set)")
plt.ylabel("fare_amount")
plt.xlabel("Distance")

plt.subplot(2, 2, 2)
plt.scatter(X_test, y_test, color = 'red')
plt.plot(X_train, l_reg.predict(X_train), color ="blue")
plt.ylabel("fare_amount")
plt.xlabel("Distance")
plt.title("Fare vs Distance (Test Set)")


plt.tight_layout()
plt.rcParams["figure.figsize"] = (32,22)
plt.show()
